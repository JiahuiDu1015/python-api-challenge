# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %%
cities
# Out:
# ['waitangi',
#  'kidal',
#  'palmer',
#  'qamdo',
#  'sao joao da barra',
#  'yellowknife',
#  'grytviken',
#  'blackmans bay',
#  'bredasdorp',
#  'moranbah',
#  'farafangana',
#  'college',
#  'tolanaro',
#  'port-aux-francais',
#  'pindushi',
#  'whakatane',
#  'malmberget',
#  'caconda',
#  'georgetown',
#  'qaqortoq',
#  'mansoa',
#  'nieves',
#  'mejit',
#  'atafu village',
#  'ushuaia',
#  'whitecourt',
#  'bethel',
#  'albany',
#  'papatowai',
#  'belmonte',
#  'kargasok',
#  'iqaluit',
#  'livadeia',
#  'punta arenas',
#  'west island',
#  'geraldton',
#  'la gi',
#  'olonkinbyen',
#  'adamstown',
#  'vorgashor',
#  'thompson',
#  'katsuura',
#  'vilyuchinsk',
#  'taiohae',
#  'ribeira grande',
#  'freetown',
#  'pacasmayo',
#  'lospalos',
#  'nova sintra',
#  'aromashevo',
#  'karaton',
#  'fort mcmurray',
#  'keflavik',
#  'roma',
#  'tiksi',
#  'edinburgh of the seven seas',
#  'port alfred',
#  'maceio',
#  'orlovskiy',
#  'palikir - national government center',
#  'huntington',
#  'silvan',
#  'hermanus',
#  'isafjordur',
#  'basi',
#  'mar del plata',
#  'zaragoza',
#  'jamestown',
#  'saipan',
#  'mugia',
#  'la passe',
#  'antsiranana',
#  'puerto natales',
#  'hithadhoo',
#  'rongelap',
#  'ilulissat',
#  'tindouf',
#  'pingzhuang',
#  'yuzhno-kurilsk',
#  'port lincoln',
#  'mabaruma',
#  'magadan',
#  'melilla',
#  'puerto ayora',
#  'quang ngai',
#  'la sarre',
#  'san clemente del tuyu',
#  'sabang',
#  'puerto baquerizo moreno',
#  'fort wellington',
#  'afaahiti',
#  'cambridge',
#  'el gouna',
#  'egilsstadir',
#  'boa vista',
#  'ashmun',
#  'puerto san carlos',
#  'anadyr',
#  'san patricio',
#  'fortuna',
#  "ust'-ilimsk",
#  'sinop',
#  'tura',
#  'hadibu',
#  'bilibino',
#  'singaparna',
#  'tanout',
#  'ahome',
#  'ust-nera',
#  'contamana',
#  'thunder bay',
#  'lubango',
#  "'ohonua",
#  'ancud',
#  'eirunepe',
#  'leninskoye',
#  'bamboo flat',
#  'kirakira',
#  'guingamp',
#  'nicoya',
#  'port mathurin',
#  'bardai',
#  'barra de santo antonio',
#  'caransebes',
#  "oboyan'",
#  'elliot',
#  'hawaiian paradise park',
#  'ta`u',
#  'qarazhal',
#  'cootamundra',
#  'utrik',
#  'san luis de la loma',
#  'katrineholm',
#  'arraial do cabo',
#  'wailua homesteads',
#  'felege neway',
#  'nahiyat ash shinafiyah',
#  'north battleford',
#  'udachny',
#  'klyuchi',
#  'fuvahmulah',
#  'aasiaat',
#  'kismayo',
#  'avarua',
#  'whitehorse',
#  'khandyga',
#  'hasaki',
#  'luau',
#  'lorengau',
#  'isangel',
#  'taibet',
#  'cabedelo',
#  'tazacorte',
#  'ende',
#  'aswan',
#  'enewetak',
#  'new norfolk',
#  'al fulah',
#  'dondo',
#  'jawf al maqbabah',
#  'horta',
#  'happy valley-goose bay',
#  'toga village',
#  'carolina',
#  'tual',
#  'ambodifotatra',
#  'tughyl',
#  'gulbene',
#  'al wafrah',
#  'zilair',
#  'mili',
#  'vylkove',
#  'mount pearl',
#  'turpan',
#  'alice springs',
#  'stanley',
#  'divnoye',
#  'mahina',
#  'rio verde',
#  'dryden',
#  'kapuskasing',
#  'monrovia',
#  'hamilton',
#  'newman',
#  'forster',
#  'saldanha',
#  'uturoa',
#  'merritt island',
#  'kataragama',
#  'wynyard',
#  'lihue',
#  'arafat',
#  'karasburg',
#  'tionk essil',
#  'labuan',
#  'qandala',
#  'alofi',
#  'motueka',
#  'reyes',
#  'argo',
#  'nelson bay',
#  'barrouallie',
#  'pangobilian',
#  'norton',
#  'hiratacho',
#  'rehoboth',
#  'okhotsk',
#  'verkhnevilyuysk',
#  'naze',
#  'pyapon',
#  'susuman',
#  'tari',
#  'tamale',
#  'lebu',
#  'carutapera',
#  'el playon',
#  'auki',
#  'duncan',
#  'takanabe',
#  'badger',
#  'vila velha',
#  'pelabuhanratu',
#  'xuanzhou',
#  'kingston',
#  'kodiak',
#  'hotan',
#  'rushville',
#  'prince rupert',
#  'kenai',
#  'sinabang',
#  "qal'at bishah",
#  'kasulu',
#  'santana',
#  'talnakh',
#  'margaret river',
#  'liupanshui',
#  'lompoc',
#  'dalandzadgad',
#  'saurimo',
#  'haiku-pauwela',
#  'port elizabeth',
#  'along',
#  'kutum',
#  'mournies',
#  'amungan',
#  'constantia',
#  'saint augustine beach',
#  'sanya',
#  'san julian',
#  'tranovaho',
#  'kodinsk',
#  'labrador city',
#  'essaouira',
#  'jijiga',
#  'pisco',
#  'neryungri',
#  'karratha',
#  'viedma',
#  'colares',
#  'klaksvik',
#  'maluso',
#  'cannonvale',
#  'broome',
#  'tobruk',
#  'murghob',
#  'inirida',
#  'isla mujeres',
#  'cargados carajos',
#  'petropavlovsk-kamchatsky',
#  'robertsport',
#  'sao vicente',
#  'pilibhit',
#  'tazovsky',
#  'aykhal',
#  'nizhneangarsk',
#  'nema',
#  'birao',
#  'shangri-la',
#  'mount gambier',
#  'ebon',
#  'nemuro',
#  'cayenne',
#  'polyarnyy',
#  'victorica',
#  'rio grande',
#  'grand falls-windsor',
#  'villa gesell',
#  'padang',
#  'takestan',
#  'arica',
#  'longyearbyen',
#  'bhimunipatnam',
#  'kroya',
#  'rabigh',
#  'yagry',
#  'floresta',
#  "sol'-iletsk",
#  'guapore',
#  'inari',
#  'mao',
#  'wotho',
#  'yuyao',
#  'touros',
#  'sharhorod',
#  'wad az zaki',
#  'kankanhalli',
#  'havre',
#  'zeliezovce',
#  'namibe',
#  'carnarvon',
#  'weno',
#  "diok'nisi",
#  'extrema',
#  'invercargill',
#  'vizinga',
#  "st. john's",
#  "nar'yan-mar",
#  'sovetskiy',
#  'kavaratti',
#  'playa vicente',
#  'castelo branco',
#  'east london',
#  'gadzhiyevo',
#  'santiago de cao',
#  'ocean shores',
#  'wuzhou',
#  'ranau',
#  'chernyshevskiy',
#  'znamenskoye',
#  'mrakovo',
#  'pasuquin',
#  'tokar',
#  'port hedland',
#  'sevastopol',
#  'virac',
#  'erdenet',
#  'levelland',
#  'tarfaya',
#  'solwezi',
#  'korla',
#  'chinde',
#  'sagalo',
#  'obanazawa',
#  'flying fish cove',
#  'broken hill',
#  'dullewala',
#  'uglegorsk',
#  'vingt cinq',
#  'aras-asan',
#  'mont-dore',
#  'colonia menno',
#  'bel ombre',
#  'razole',
#  'amos',
#  'ola',
#  'blackfoot',
#  'tidjikja',
#  'kamaishi',
#  'onguday',
#  'fiambala',
#  'island harbour',
#  'itoman',
#  'la ronge',
#  'cidreira',
#  'porto belo',
#  'portland',
#  'san jose de feliciano',
#  'talas',
#  'iskateley',
#  'meadville',
#  'arno',
#  'howard springs',
#  'porto novo',
#  'port blair',
#  'lower hutt',
#  'qulsary',
#  'dhaulpur',
#  'kongsvinger',
#  'miyanoura',
#  "mil'kovo",
#  'jau',
#  'danjiangkou',
#  'kapoeta',
#  'holma',
#  'ciudad lazaro cardenas',
#  'maloye ganyushkino',
#  'san pedro',
#  'kyshtovka',
#  'al ghayzah',
#  'koson',
#  'araxa',
#  'paka',
#  'harstad',
#  'chibougamau',
#  'remire-montjoly',
#  'formosa do rio preto',
#  'tenno',
#  'gao',
#  'yanam',
#  'nefteyugansk',
#  'tsiombe',
#  'markovo',
#  'empangeni',
#  'rurrenabaque',
#  'adigrat',
#  'terrace',
#  'roxas',
#  'chapada dos guimaraes',
#  'filadelfia',
#  'woodcrest',
#  'ponta delgada',
#  "'alaqahdari dishu",
#  'arroyo seco',
#  'najran',
#  'solnechnyy',
#  'artova',
#  'marudi',
#  'dudinka',
#  'quellon',
#  'prainha',
#  'malango',
#  'baruun-urt',
#  'bilozerka',
#  'ayvacik',
#  'kyabe',
#  'beyneu',
#  'taitung city',
#  'kerikeri',
#  'dapa',
#  'meizhou',
#  'bida',
#  'shitanjing',
#  'kitami',
#  'luderitz',
#  'saint-pierre',
#  'porkhov',
#  'lhasa',
#  'nikolayevsk-on-amure',
#  'orsa',
#  'bodo',
#  'kamennomostskiy',
#  'tralee',
#  'nizhnesortymskiy',
#  'vasto',
#  'arar',
#  'taraz',
#  'oranjemund',
#  'vohipaho',
#  'serra',
#  'bani walid',
#  'praya',
#  'savanna-la-mar',
#  'necochea',
#  'fale old settlement',
#  'kolonia town',
#  'tobelo',
#  'laojunmiao',
#  'al muwayh',
#  'vanino',
#  'swidnik',
#  'kone',
#  'kununurra',
#  'limon',
#  'kruisfontein',
#  'grand gaube',
#  'yinchuan',
#  'hammerfest',
#  'herkimer',
#  'usogorsk',
#  'nuuk',
#  'rabaul',
#  'belomorsk',
#  'shushenskoye',
#  'siyabuswa',
#  'jinchang',
#  'nkurenkuru',
#  'sabana de torres',
#  'salalah',
#  'tsengel',
#  'del rio',
#  'matoury',
#  'aldama',
#  'selfoss',
#  'holualoa',
#  'safford',
#  "ivdel'",
#  'mata-utu',
#  'as sulayyil',
#  'hacilar',
#  'mwene-ditu',
#  'castillos',
#  'ad dawadimi',
#  'praia da vitoria',
#  'shanhaiguan',
#  'commerce',
#  'bubaque',
#  'nantucket',
#  'birobidzhan',
#  'pingliang',
#  'amga',
#  'barreiro do jaiba',
#  'talakan',
#  'shingu',
#  'egersund',
#  'luba',
#  'coquimbo',
#  'beichengqu',
#  'lerwick',
#  'howrah',
#  'isle of lewis',
#  'christchurch',
#  'erenhot',
#  'ust-tsilma',
#  'sona',
#  'yeed',
#  'dire dawa',
#  'sisimiut',
#  'mumbwa',
#  'tamanrasset',
#  'crane',
#  'tachilek',
#  'zolochiv',
#  'richards bay',
#  'linqiong',
#  'colonia',
#  'kyaikkami',
#  "chul'man",
#  'alotau',
#  'ouani',
#  'jeonju',
#  'iwanai',
#  'coyhaique',
#  'sant carles de la rapita',
#  'ciudad bolivar',
#  'vyazemskiy',
#  'bayan',
#  'novyy urengoy',
#  'sault ste. marie',
#  'antofagasta',
#  'apia',
#  'caleta de carquin',
#  "ust'-barguzin",
#  'port augusta',
#  'sola',
#  'minab',
#  'askiz',
#  'irymple',
#  'puerto armuelles',
#  'saint-philippe',
#  'banda aceh',
#  'kaa-khem',
#  'hwange',
#  'gorom-gorom',
#  'tofol',
#  'paita',
#  'kwaksan',
#  'emerald',
#  'palu',
#  'mo i rana',
#  'shiyan',
#  "ma'rib",
#  'olinda',
#  'lalsot',
#  'krasnogorskoye',
#  'three points',
#  'bakanas',
#  'kowon-up',
#  'siwa oasis',
#  'east ballina',
#  'bambanglipuro',
#  'talcahuano',
#  'tanrake village',
#  'hirara',
#  'smithers',
#  'laguna',
#  'agat village',
#  'kuta',
#  'saudarkrokur',
#  'saint-joseph',
#  'chernushka',
#  'horodok',
#  'arish',
#  'bouinan',
#  'turkestan',
#  'manuel ojinaga',
#  'trinity beach',
#  'mamuju',
#  'cerkezkoy',
#  'gagliano del capo']

# %%
lats
# Out:
# array([-84.39744413,  18.36639552,  61.06291259, ...,  -6.18456919,
#         73.1713123 , -43.20742372])

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID="+weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_json = city_weather.json()
    
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json['coord']['lat']
        city_lng = city_json['coord']['lon']
        city_max_temp = city_json['main']['temp_max']
        city_humidity = city_json['main']['humidity']
        city_clouds =  city_json['clouds']['all']
        city_wind = city_json['wind']['speed']
        city_country = city_json['sys']['country']
        city_date = city_json['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | kidal
# Processing Record 3 of Set 1 | palmer
# Processing Record 4 of Set 1 | qamdo
# Processing Record 5 of Set 1 | sao joao da barra
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | moranbah
# Processing Record 11 of Set 1 | farafangana
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | tolanaro
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | pindushi
# Processing Record 16 of Set 1 | whakatane
# Processing Record 17 of Set 1 | malmberget
# Processing Record 18 of Set 1 | caconda
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | mansoa
# Processing Record 22 of Set 1 | nieves
# Processing Record 23 of Set 1 | mejit
# Processing Record 24 of Set 1 | atafu village
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | whitecourt
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | papatowai
# Processing Record 30 of Set 1 | belmonte
# Processing Record 31 of Set 1 | kargasok
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | livadeia
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | west island
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | la gi
# Processing Record 38 of Set 1 | olonkinbyen
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | vorgashor
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | vilyuchinsk
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | freetown
# Processing Record 47 of Set 1 | pacasmayo
# Processing Record 48 of Set 1 | lospalos
# Processing Record 49 of Set 1 | nova sintra
# Processing Record 50 of Set 1 | aromashevo
# Processing Record 0 of Set 2 | karaton
# Processing Record 1 of Set 2 | fort mcmurray
# Processing Record 2 of Set 2 | keflavik
# Processing Record 3 of Set 2 | roma
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | edinburgh of the seven seas
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | maceio
# Processing Record 8 of Set 2 | orlovskiy
# Processing Record 9 of Set 2 | palikir - national government center
# Processing Record 10 of Set 2 | huntington
# Processing Record 11 of Set 2 | silvan
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | isafjordur
# Processing Record 14 of Set 2 | basi
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | zaragoza
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | saipan
# Processing Record 19 of Set 2 | mugia
# Processing Record 20 of Set 2 | la passe
# Processing Record 21 of Set 2 | antsiranana
# Processing Record 22 of Set 2 | puerto natales
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | rongelap
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | tindouf
# Processing Record 27 of Set 2 | pingzhuang
# Processing Record 28 of Set 2 | yuzhno-kurilsk
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | mabaruma
# Processing Record 31 of Set 2 | magadan
# Processing Record 32 of Set 2 | melilla
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | quang ngai
# Processing Record 35 of Set 2 | la sarre
# Processing Record 36 of Set 2 | san clemente del tuyu
# Processing Record 37 of Set 2 | sabang
# Processing Record 38 of Set 2 | puerto baquerizo moreno
# Processing Record 39 of Set 2 | fort wellington
# Processing Record 40 of Set 2 | afaahiti
# Processing Record 41 of Set 2 | cambridge
# Processing Record 42 of Set 2 | el gouna
# Processing Record 43 of Set 2 | egilsstadir
# Processing Record 44 of Set 2 | boa vista
# Processing Record 45 of Set 2 | ashmun
# Processing Record 46 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 47 of Set 2 | anadyr
# Processing Record 48 of Set 2 | san patricio
# Processing Record 49 of Set 2 | fortuna
# Processing Record 0 of Set 3 | ust'-ilimsk
# Processing Record 1 of Set 3 | sinop
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | hadibu
# Processing Record 4 of Set 3 | bilibino
# Processing Record 5 of Set 3 | singaparna
# Processing Record 6 of Set 3 | tanout
# Processing Record 7 of Set 3 | ahome
# Processing Record 8 of Set 3 | ust-nera
# Processing Record 9 of Set 3 | contamana
# Processing Record 10 of Set 3 | thunder bay
# Processing Record 11 of Set 3 | lubango
# Processing Record 12 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | eirunepe
# Processing Record 15 of Set 3 | leninskoye
# Processing Record 16 of Set 3 | bamboo flat
# Processing Record 17 of Set 3 | kirakira
# Processing Record 18 of Set 3 | guingamp
# Processing Record 19 of Set 3 | nicoya
# Processing Record 20 of Set 3 | port mathurin
# Processing Record 21 of Set 3 | bardai
# Processing Record 22 of Set 3 | barra de santo antonio
# Processing Record 23 of Set 3 | caransebes
# Processing Record 24 of Set 3 | oboyan'
# Processing Record 25 of Set 3 | elliot
# Processing Record 26 of Set 3 | hawaiian paradise park
# Processing Record 27 of Set 3 | ta`u
# Processing Record 28 of Set 3 | qarazhal
# Processing Record 29 of Set 3 | cootamundra
# Processing Record 30 of Set 3 | utrik
# Processing Record 31 of Set 3 | san luis de la loma
# Processing Record 32 of Set 3 | katrineholm
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | wailua homesteads
# Processing Record 35 of Set 3 | felege neway
# Processing Record 36 of Set 3 | nahiyat ash shinafiyah
# Processing Record 37 of Set 3 | north battleford
# Processing Record 38 of Set 3 | udachny
# Processing Record 39 of Set 3 | klyuchi
# Processing Record 40 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 3 | aasiaat
# Processing Record 42 of Set 3 | kismayo
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | whitehorse
# Processing Record 45 of Set 3 | khandyga
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | luau
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | isangel
# Processing Record 0 of Set 4 | taibet
# City not found. Skipping...
# Processing Record 1 of Set 4 | cabedelo
# Processing Record 2 of Set 4 | tazacorte
# Processing Record 3 of Set 4 | ende
# Processing Record 4 of Set 4 | aswan
# Processing Record 5 of Set 4 | enewetak
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | al fulah
# Processing Record 8 of Set 4 | dondo
# Processing Record 9 of Set 4 | jawf al maqbabah
# Processing Record 10 of Set 4 | horta
# Processing Record 11 of Set 4 | happy valley-goose bay
# Processing Record 12 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 4 | carolina
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | ambodifotatra
# Processing Record 16 of Set 4 | tughyl
# Processing Record 17 of Set 4 | gulbene
# Processing Record 18 of Set 4 | al wafrah
# Processing Record 19 of Set 4 | zilair
# Processing Record 20 of Set 4 | mili
# Processing Record 21 of Set 4 | vylkove
# Processing Record 22 of Set 4 | mount pearl
# Processing Record 23 of Set 4 | turpan
# Processing Record 24 of Set 4 | alice springs
# Processing Record 25 of Set 4 | stanley
# Processing Record 26 of Set 4 | divnoye
# Processing Record 27 of Set 4 | mahina
# Processing Record 28 of Set 4 | rio verde
# Processing Record 29 of Set 4 | dryden
# Processing Record 30 of Set 4 | kapuskasing
# Processing Record 31 of Set 4 | monrovia
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | newman
# Processing Record 34 of Set 4 | forster
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | uturoa
# Processing Record 37 of Set 4 | merritt island
# Processing Record 38 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 39 of Set 4 | wynyard
# Processing Record 40 of Set 4 | lihue
# Processing Record 41 of Set 4 | arafat
# Processing Record 42 of Set 4 | karasburg
# Processing Record 43 of Set 4 | tionk essil
# Processing Record 44 of Set 4 | labuan
# Processing Record 45 of Set 4 | qandala
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | motueka
# Processing Record 48 of Set 4 | reyes
# Processing Record 49 of Set 4 | argo
# Processing Record 0 of Set 5 | nelson bay
# Processing Record 1 of Set 5 | barrouallie
# Processing Record 2 of Set 5 | pangobilian
# Processing Record 3 of Set 5 | norton
# Processing Record 4 of Set 5 | hiratacho
# Processing Record 5 of Set 5 | rehoboth
# Processing Record 6 of Set 5 | okhotsk
# Processing Record 7 of Set 5 | verkhnevilyuysk
# Processing Record 8 of Set 5 | naze
# Processing Record 9 of Set 5 | pyapon
# Processing Record 10 of Set 5 | susuman
# Processing Record 11 of Set 5 | tari
# Processing Record 12 of Set 5 | tamale
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | el playon
# Processing Record 16 of Set 5 | auki
# Processing Record 17 of Set 5 | duncan
# Processing Record 18 of Set 5 | takanabe
# Processing Record 19 of Set 5 | badger
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | pelabuhanratu
# Processing Record 22 of Set 5 | xuanzhou
# Processing Record 23 of Set 5 | kingston
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | hotan
# Processing Record 26 of Set 5 | rushville
# Processing Record 27 of Set 5 | prince rupert
# Processing Record 28 of Set 5 | kenai
# Processing Record 29 of Set 5 | sinabang
# Processing Record 30 of Set 5 | qal'at bishah
# City not found. Skipping...
# Processing Record 31 of Set 5 | kasulu
# Processing Record 32 of Set 5 | santana
# Processing Record 33 of Set 5 | talnakh
# Processing Record 34 of Set 5 | margaret river
# Processing Record 35 of Set 5 | liupanshui
# City not found. Skipping...
# Processing Record 36 of Set 5 | lompoc
# Processing Record 37 of Set 5 | dalandzadgad
# Processing Record 38 of Set 5 | saurimo
# Processing Record 39 of Set 5 | haiku-pauwela
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | along
# Processing Record 42 of Set 5 | kutum
# Processing Record 43 of Set 5 | mournies
# Processing Record 44 of Set 5 | amungan
# Processing Record 45 of Set 5 | constantia
# Processing Record 46 of Set 5 | saint augustine beach
# Processing Record 47 of Set 5 | sanya
# Processing Record 48 of Set 5 | san julian
# Processing Record 49 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 0 of Set 6 | kodinsk
# Processing Record 1 of Set 6 | labrador city
# Processing Record 2 of Set 6 | essaouira
# Processing Record 3 of Set 6 | jijiga
# Processing Record 4 of Set 6 | pisco
# Processing Record 5 of Set 6 | neryungri
# Processing Record 6 of Set 6 | karratha
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | colares
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | maluso
# Processing Record 11 of Set 6 | cannonvale
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | tobruk
# Processing Record 14 of Set 6 | murghob
# Processing Record 15 of Set 6 | inirida
# Processing Record 16 of Set 6 | isla mujeres
# Processing Record 17 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 6 | robertsport
# Processing Record 20 of Set 6 | sao vicente
# Processing Record 21 of Set 6 | pilibhit
# Processing Record 22 of Set 6 | tazovsky
# Processing Record 23 of Set 6 | aykhal
# Processing Record 24 of Set 6 | nizhneangarsk
# Processing Record 25 of Set 6 | nema
# Processing Record 26 of Set 6 | birao
# Processing Record 27 of Set 6 | shangri-la
# City not found. Skipping...
# Processing Record 28 of Set 6 | mount gambier
# Processing Record 29 of Set 6 | ebon
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | polyarnyy
# Processing Record 33 of Set 6 | victorica
# Processing Record 34 of Set 6 | rio grande
# Processing Record 35 of Set 6 | grand falls-windsor
# Processing Record 36 of Set 6 | villa gesell
# Processing Record 37 of Set 6 | padang
# Processing Record 38 of Set 6 | takestan
# Processing Record 39 of Set 6 | arica
# Processing Record 40 of Set 6 | longyearbyen
# Processing Record 41 of Set 6 | bhimunipatnam
# Processing Record 42 of Set 6 | kroya
# Processing Record 43 of Set 6 | rabigh
# Processing Record 44 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 45 of Set 6 | floresta
# Processing Record 46 of Set 6 | sol'-iletsk
# Processing Record 47 of Set 6 | guapore
# Processing Record 48 of Set 6 | inari
# Processing Record 49 of Set 6 | mao
# Processing Record 0 of Set 7 | wotho
# Processing Record 1 of Set 7 | yuyao
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | sharhorod
# Processing Record 4 of Set 7 | wad az zaki
# Processing Record 5 of Set 7 | kankanhalli
# Processing Record 6 of Set 7 | havre
# Processing Record 7 of Set 7 | zeliezovce
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | carnarvon
# Processing Record 10 of Set 7 | weno
# Processing Record 11 of Set 7 | diok'nisi
# Processing Record 12 of Set 7 | extrema
# Processing Record 13 of Set 7 | invercargill
# Processing Record 14 of Set 7 | vizinga
# Processing Record 15 of Set 7 | st. john's
# Processing Record 16 of Set 7 | nar'yan-mar
# Processing Record 17 of Set 7 | sovetskiy
# Processing Record 18 of Set 7 | kavaratti
# Processing Record 19 of Set 7 | playa vicente
# Processing Record 20 of Set 7 | castelo branco
# Processing Record 21 of Set 7 | east london
# Processing Record 22 of Set 7 | gadzhiyevo
# Processing Record 23 of Set 7 | santiago de cao
# Processing Record 24 of Set 7 | ocean shores
# Processing Record 25 of Set 7 | wuzhou
# Processing Record 26 of Set 7 | ranau
# Processing Record 27 of Set 7 | chernyshevskiy
# Processing Record 28 of Set 7 | znamenskoye
# Processing Record 29 of Set 7 | mrakovo
# Processing Record 30 of Set 7 | pasuquin
# Processing Record 31 of Set 7 | tokar
# Processing Record 32 of Set 7 | port hedland
# Processing Record 33 of Set 7 | sevastopol
# Processing Record 34 of Set 7 | virac
# Processing Record 35 of Set 7 | erdenet
# Processing Record 36 of Set 7 | levelland
# Processing Record 37 of Set 7 | tarfaya
# Processing Record 38 of Set 7 | solwezi
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | chinde
# Processing Record 41 of Set 7 | sagalo
# City not found. Skipping...
# Processing Record 42 of Set 7 | obanazawa
# Processing Record 43 of Set 7 | flying fish cove
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | dullewala
# Processing Record 46 of Set 7 | uglegorsk
# Processing Record 47 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 7 | aras-asan
# Processing Record 49 of Set 7 | mont-dore
# Processing Record 0 of Set 8 | colonia menno
# Processing Record 1 of Set 8 | bel ombre
# Processing Record 2 of Set 8 | razole
# Processing Record 3 of Set 8 | amos
# Processing Record 4 of Set 8 | ola
# Processing Record 5 of Set 8 | blackfoot
# Processing Record 6 of Set 8 | tidjikja
# Processing Record 7 of Set 8 | kamaishi
# Processing Record 8 of Set 8 | onguday
# Processing Record 9 of Set 8 | fiambala
# Processing Record 10 of Set 8 | island harbour
# Processing Record 11 of Set 8 | itoman
# Processing Record 12 of Set 8 | la ronge
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | porto belo
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | san jose de feliciano
# Processing Record 17 of Set 8 | talas
# Processing Record 18 of Set 8 | iskateley
# Processing Record 19 of Set 8 | meadville
# Processing Record 20 of Set 8 | arno
# Processing Record 21 of Set 8 | howard springs
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | port blair
# Processing Record 24 of Set 8 | lower hutt
# Processing Record 25 of Set 8 | qulsary
# Processing Record 26 of Set 8 | dhaulpur
# Processing Record 27 of Set 8 | kongsvinger
# Processing Record 28 of Set 8 | miyanoura
# City not found. Skipping...
# Processing Record 29 of Set 8 | mil'kovo
# Processing Record 30 of Set 8 | jau
# Processing Record 31 of Set 8 | danjiangkou
# Processing Record 32 of Set 8 | kapoeta
# Processing Record 33 of Set 8 | holma
# Processing Record 34 of Set 8 | ciudad lazaro cardenas
# Processing Record 35 of Set 8 | maloye ganyushkino
# Processing Record 36 of Set 8 | san pedro
# Processing Record 37 of Set 8 | kyshtovka
# Processing Record 38 of Set 8 | al ghayzah
# Processing Record 39 of Set 8 | koson
# Processing Record 40 of Set 8 | araxa
# Processing Record 41 of Set 8 | paka
# Processing Record 42 of Set 8 | harstad
# Processing Record 43 of Set 8 | chibougamau
# Processing Record 44 of Set 8 | remire-montjoly
# Processing Record 45 of Set 8 | formosa do rio preto
# Processing Record 46 of Set 8 | tenno
# Processing Record 47 of Set 8 | gao
# Processing Record 48 of Set 8 | yanam
# Processing Record 49 of Set 8 | nefteyugansk
# Processing Record 0 of Set 9 | tsiombe
# Processing Record 1 of Set 9 | markovo
# Processing Record 2 of Set 9 | empangeni
# Processing Record 3 of Set 9 | rurrenabaque
# Processing Record 4 of Set 9 | adigrat
# Processing Record 5 of Set 9 | terrace
# Processing Record 6 of Set 9 | roxas
# Processing Record 7 of Set 9 | chapada dos guimaraes
# Processing Record 8 of Set 9 | filadelfia
# Processing Record 9 of Set 9 | woodcrest
# Processing Record 10 of Set 9 | ponta delgada
# Processing Record 11 of Set 9 | 'alaqahdari dishu
# Processing Record 12 of Set 9 | arroyo seco
# Processing Record 13 of Set 9 | najran
# Processing Record 14 of Set 9 | solnechnyy
# Processing Record 15 of Set 9 | artova
# Processing Record 16 of Set 9 | marudi
# City not found. Skipping...
# Processing Record 17 of Set 9 | dudinka
# Processing Record 18 of Set 9 | quellon
# Processing Record 19 of Set 9 | prainha
# Processing Record 20 of Set 9 | malango
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | bilozerka
# Processing Record 23 of Set 9 | ayvacik
# Processing Record 24 of Set 9 | kyabe
# Processing Record 25 of Set 9 | beyneu
# Processing Record 26 of Set 9 | taitung city
# Processing Record 27 of Set 9 | kerikeri
# Processing Record 28 of Set 9 | dapa
# Processing Record 29 of Set 9 | meizhou
# Processing Record 30 of Set 9 | bida
# Processing Record 31 of Set 9 | shitanjing
# Processing Record 32 of Set 9 | kitami
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | porkhov
# Processing Record 36 of Set 9 | lhasa
# Processing Record 37 of Set 9 | nikolayevsk-on-amure
# Processing Record 38 of Set 9 | orsa
# Processing Record 39 of Set 9 | bodo
# Processing Record 40 of Set 9 | kamennomostskiy
# Processing Record 41 of Set 9 | tralee
# Processing Record 42 of Set 9 | nizhnesortymskiy
# Processing Record 43 of Set 9 | vasto
# Processing Record 44 of Set 9 | arar
# Processing Record 45 of Set 9 | taraz
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | vohipaho
# City not found. Skipping...
# Processing Record 48 of Set 9 | serra
# Processing Record 49 of Set 9 | bani walid
# Processing Record 0 of Set 10 | praya
# Processing Record 1 of Set 10 | savanna-la-mar
# Processing Record 2 of Set 10 | necochea
# Processing Record 3 of Set 10 | fale old settlement
# Processing Record 4 of Set 10 | kolonia town
# Processing Record 5 of Set 10 | tobelo
# Processing Record 6 of Set 10 | laojunmiao
# Processing Record 7 of Set 10 | al muwayh
# Processing Record 8 of Set 10 | vanino
# Processing Record 9 of Set 10 | swidnik
# Processing Record 10 of Set 10 | kone
# Processing Record 11 of Set 10 | kununurra
# Processing Record 12 of Set 10 | limon
# Processing Record 13 of Set 10 | kruisfontein
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | yinchuan
# Processing Record 16 of Set 10 | hammerfest
# Processing Record 17 of Set 10 | herkimer
# Processing Record 18 of Set 10 | usogorsk
# Processing Record 19 of Set 10 | nuuk
# Processing Record 20 of Set 10 | rabaul
# Processing Record 21 of Set 10 | belomorsk
# Processing Record 22 of Set 10 | shushenskoye
# Processing Record 23 of Set 10 | siyabuswa
# Processing Record 24 of Set 10 | jinchang
# Processing Record 25 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 26 of Set 10 | sabana de torres
# Processing Record 27 of Set 10 | salalah
# Processing Record 28 of Set 10 | tsengel
# Processing Record 29 of Set 10 | del rio
# Processing Record 30 of Set 10 | matoury
# Processing Record 31 of Set 10 | aldama
# Processing Record 32 of Set 10 | selfoss
# Processing Record 33 of Set 10 | holualoa
# Processing Record 34 of Set 10 | safford
# Processing Record 35 of Set 10 | ivdel'
# Processing Record 36 of Set 10 | mata-utu
# Processing Record 37 of Set 10 | as sulayyil
# Processing Record 38 of Set 10 | hacilar
# Processing Record 39 of Set 10 | mwene-ditu
# Processing Record 40 of Set 10 | castillos
# Processing Record 41 of Set 10 | ad dawadimi
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | shanhaiguan
# Processing Record 44 of Set 10 | commerce
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | nantucket
# Processing Record 47 of Set 10 | birobidzhan
# Processing Record 48 of Set 10 | pingliang
# Processing Record 49 of Set 10 | amga
# Processing Record 0 of Set 11 | barreiro do jaiba
# Processing Record 1 of Set 11 | talakan
# Processing Record 2 of Set 11 | shingu
# Processing Record 3 of Set 11 | egersund
# Processing Record 4 of Set 11 | luba
# Processing Record 5 of Set 11 | coquimbo
# Processing Record 6 of Set 11 | beichengqu
# Processing Record 7 of Set 11 | lerwick
# Processing Record 8 of Set 11 | howrah
# Processing Record 9 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 10 of Set 11 | christchurch
# Processing Record 11 of Set 11 | erenhot
# Processing Record 12 of Set 11 | ust-tsilma
# Processing Record 13 of Set 11 | sona
# Processing Record 14 of Set 11 | yeed
# Processing Record 15 of Set 11 | dire dawa
# Processing Record 16 of Set 11 | sisimiut
# Processing Record 17 of Set 11 | mumbwa
# Processing Record 18 of Set 11 | tamanrasset
# Processing Record 19 of Set 11 | crane
# Processing Record 20 of Set 11 | tachilek
# City not found. Skipping...
# Processing Record 21 of Set 11 | zolochiv
# Processing Record 22 of Set 11 | richards bay
# Processing Record 23 of Set 11 | linqiong
# Processing Record 24 of Set 11 | colonia
# Processing Record 25 of Set 11 | kyaikkami
# Processing Record 26 of Set 11 | chul'man
# Processing Record 27 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 11 | ouani
# Processing Record 29 of Set 11 | jeonju
# Processing Record 30 of Set 11 | iwanai
# Processing Record 31 of Set 11 | coyhaique
# Processing Record 32 of Set 11 | sant carles de la rapita
# Processing Record 33 of Set 11 | ciudad bolivar
# Processing Record 34 of Set 11 | vyazemskiy
# Processing Record 35 of Set 11 | bayan
# Processing Record 36 of Set 11 | novyy urengoy
# Processing Record 37 of Set 11 | sault ste. marie
# Processing Record 38 of Set 11 | antofagasta
# Processing Record 39 of Set 11 | apia
# Processing Record 40 of Set 11 | caleta de carquin
# Processing Record 41 of Set 11 | ust'-barguzin
# Processing Record 42 of Set 11 | port augusta
# Processing Record 43 of Set 11 | sola
# Processing Record 44 of Set 11 | minab
# Processing Record 45 of Set 11 | askiz
# Processing Record 46 of Set 11 | irymple
# Processing Record 47 of Set 11 | puerto armuelles
# Processing Record 48 of Set 11 | saint-philippe
# Processing Record 49 of Set 11 | banda aceh
# Processing Record 0 of Set 12 | kaa-khem
# Processing Record 1 of Set 12 | hwange
# Processing Record 2 of Set 12 | gorom-gorom
# Processing Record 3 of Set 12 | tofol
# Processing Record 4 of Set 12 | paita
# Processing Record 5 of Set 12 | kwaksan
# Processing Record 6 of Set 12 | emerald
# Processing Record 7 of Set 12 | palu
# Processing Record 8 of Set 12 | mo i rana
# Processing Record 9 of Set 12 | shiyan
# Processing Record 10 of Set 12 | ma'rib
# Processing Record 11 of Set 12 | olinda
# Processing Record 12 of Set 12 | lalsot
# Processing Record 13 of Set 12 | krasnogorskoye
# Processing Record 14 of Set 12 | three points
# Processing Record 15 of Set 12 | bakanas
# Processing Record 16 of Set 12 | kowon-up
# Processing Record 17 of Set 12 | siwa oasis
# City not found. Skipping...
# Processing Record 18 of Set 12 | east ballina
# City not found. Skipping...
# Processing Record 19 of Set 12 | bambanglipuro
# Processing Record 20 of Set 12 | talcahuano
# Processing Record 21 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 22 of Set 12 | hirara
# Processing Record 23 of Set 12 | smithers
# Processing Record 24 of Set 12 | laguna
# Processing Record 25 of Set 12 | agat village
# Processing Record 26 of Set 12 | kuta
# Processing Record 27 of Set 12 | saudarkrokur
# Processing Record 28 of Set 12 | saint-joseph
# Processing Record 29 of Set 12 | chernushka
# Processing Record 30 of Set 12 | horodok
# Processing Record 31 of Set 12 | arish
# Processing Record 32 of Set 12 | bouinan
# Processing Record 33 of Set 12 | turkestan
# Processing Record 34 of Set 12 | manuel ojinaga
# City not found. Skipping...
# Processing Record 35 of Set 12 | trinity beach
# Processing Record 36 of Set 12 | mamuju
# Processing Record 37 of Set 12 | cerkezkoy
# Processing Record 38 of Set 12 | gagliano del capo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           waitangi -43.9535 -176.5597      7.68        97          98
# 1              kidal  18.4411    1.4078     38.25        29          30
# 2             palmer  42.1584  -72.3287     20.69        82          40
# 3              qamdo  31.1667   97.2333      6.65        86          99
# 4  sao joao da barra -21.6403  -41.0511     20.05        74           0
#
#    Wind Speed Country        Date
# 0        1.79      NZ  1720007214
# 1        7.51      ML  1720007215
# 2        0.00      US  1720007140
# 3        2.59      CN  1720007219
# 4        3.77      BR  1720007220

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597      7.68        97          98
# 1                    kidal  18.4411    1.4078     38.25        29          30
# 2                   palmer  42.1584  -72.3287     20.69        82          40
# 3                    qamdo  31.1667   97.2333      6.65        86          99
# 4        sao joao da barra -21.6403  -41.0511     20.05        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      NZ  1720007214
# 1              7.51      ML  1720007215
# 2              0.00      US  1720007140
# 3              2.59      CN  1720007219
# 4              3.77      BR  1720007220

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f"City Latitude vs Max Temperature(2024-06-29)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title(f"City Latitude vs Humidity(2024-06-29)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title(f"City Latitude vs Cloudiness(2024-06-29)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title(f"City Latitude vs Cloudiness(2024-06-29)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
def plot_linear_regression(x_values, y_values, x_label, y_label, title):
    
# Get regression values
 regress_values = x_values * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
north_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              kidal  18.4411    1.4078     38.25        29          30
# 2             palmer  42.1584  -72.3287     20.69        82          40
# 3              qamdo  31.1667   97.2333      6.65        86          99
# 5        yellowknife  62.4560 -114.3525     12.29        94          75
# 11           college  64.8569 -147.8028     17.32        63          75
#
#          Wind Speed Country        Date
# City_ID
# 1              7.51      ML  1720007215
# 2              0.00      US  1720007140
# 3              2.59      CN  1720007219
# 5              2.57      CA  1720007077
# 11             3.60      US  1720007229

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
south_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597      7.68        97          98
# 4        sao joao da barra -21.6403  -41.0511     20.05        74           0
# 6                grytviken -54.2811  -36.5092     -4.80        74           8
# 7            blackmans bay -43.0167  147.3167      6.52        85          19
# 8               bredasdorp -34.5322   20.0403     13.41        82          93
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      NZ  1720007214
# 4              3.77      BR  1720007220
# 6              3.11      GS  1720007223
# 7              0.45      AU  1720007224
# 8              2.43      ZA  1720007225

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_north_hemi = north_hemi_df['Lat']
y_values_north_hemi = north_hemi_df['Max Temp']


# Linear regression on Northern Hemisphere 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north_hemi, y_values_north_hemi)
regress_values_north_hemi = x_values_north_hemi * slope + intercept
print(regress_values_north_hemi)

# Create Plot
plt.scatter(x_values_north_hemi,y_values_north_hemi)
plt.plot(x_values_north_hemi,regress_values_north_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(0,3),fontsize=15,color="red")
plt.title(f"Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 1      28.803489
# 2      22.553587
# 3      25.450082
# 5      17.204833
# 11     16.572157
#          ...
# 556    25.459332
# 557    24.036316
# 558    22.243982
# 561    22.783743
# 562    23.163417
# Name: Lat, Length: 396, dtype: float64
# The r^2-value is: 0.3852397530531541

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_south_hemi = south_hemi_df['Lat']
y_values_south_hemi = south_hemi_df['Max Temp']

# Linear regression on Southern Hemisphere 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south_hemi, y_values_south_hemi)
regress_values_south_hemi = x_values_south_hemi * slope + intercept

print(regress_values_south_hemi)

# Create Plot
plt.scatter(x_values_south_hemi,y_values_south_hemi)
plt.plot(x_values_south_hemi,regress_values_south_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-56,35),fontsize=15,color="red")
plt.title(f"Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 0       6.706580
# 4      18.641485
# 6       1.182544
# 7       7.207657
# 8      11.745854
#          ...
# 546    10.577406
# 551    25.550541
# 553    18.787828
# 559    21.236459
# 560    28.785768
# Name: Lat, Length: 167, dtype: float64
# The r^2-value is: 0.6981068762104976

# %%
filtered_south_hemi_df = south_hemi_df.dropna(subset=['Lat', 'Max Temp'])
filtered_south_hemi_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597      7.68        97          98
# 4        sao joao da barra -21.6403  -41.0511     20.05        74           0
# 6                grytviken -54.2811  -36.5092     -4.80        74           8
# 7            blackmans bay -43.0167  147.3167      6.52        85          19
# 8               bredasdorp -34.5322   20.0403     13.41        82          93
# ...                    ...      ...       ...       ...       ...         ...
# 546             talcahuano -36.7167  -73.1167      7.53        78          99
# 551                   kuta  -8.7233  115.1723     25.97        94          75
# 553           saint-joseph -21.3667   55.6167     22.21        76          13
# 559          trinity beach -16.7888  145.6968     22.94        84         100
# 560                 mamuju  -2.6748  118.8885     24.32        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      NZ  1720007214
# 4              3.77      BR  1720007220
# 6              3.11      GS  1720007223
# 7              0.45      AU  1720007224
# 8              2.43      ZA  1720007225
# ...             ...     ...         ...
# 546            3.39      CL  1720008017
# 551            4.63      ID  1720008031
# 553            7.63      RE  1720008035
# 559            4.12      AU  1720008047
# 560            3.31      ID  1720008048
#
# [167 rows x 9 columns]

# %%
num_rows_lat = len(filtered_south_hemi_df['Lat'])
num_rows_lat
# Out:
# 167

# %%
num_rows_max_temp = len(filtered_south_hemi_df['Max Temp'])
num_rows_max_temp
# Out:
# 167

# %% [markdown]
# **Discussion about the linear relationship:**

# %%
The r^2-value is: 0.3852397530531541 for north hemisphere which indicates a weak positive linear relationship between the latiture and the maximume tempreture, while it shows a 
strong positive linear relationship for south hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_north_hemi = north_hemi_df['Lat']
y_values_north_hemi = north_hemi_df['Humidity']

# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north_hemi, y_values_north_hemi)
regress_values_north_hemi = x_values_north_hemi * slope + intercept
print(regress_values_north_hemi)

# Create Plot
plt.scatter(x_values_north_hemi,y_values_north_hemi)
plt.plot(x_values_north_hemi,regress_values_north_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.title(f"Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 1      66.296723
# 2      66.789243
# 3      66.560986
# 5      67.210748
# 11     67.260606
#          ...
# 556    66.560257
# 557    66.672397
# 558    66.813641
# 561    66.771106
# 562    66.741186
# Name: Lat, Length: 396, dtype: float64
# The r^2-value is: 0.00024362370449617163

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_south_hemi = south_hemi_df['Lat']
y_values_south_hemi = south_hemi_df['Humidity']


# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south_hemi, y_values_south_hemi)
regress_values_south_hemi = x_values_south_hemi * slope + intercept
print(regress_values_south_hemi)

# Create Plot
plt.scatter(x_values_south_hemi,y_values_south_hemi)
plt.plot(x_values_south_hemi,regress_values_south_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-54,18),fontsize=15,color="red")
plt.title(f"Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 0      71.534801
# 4      70.872730
# 6      71.841240
# 7      71.507005
# 8      71.255255
#          ...
# 546    71.320073
# 551    70.489460
# 553    70.864611
# 559    70.728777
# 560    70.309990
# Name: Lat, Length: 167, dtype: float64
# The r^2-value is: 0.0002699108169265346

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
 There are no linear relationship between latitute and humidity for both south and north hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_north_hemi = north_hemi_df['Lat']
y_values_north_hemi = north_hemi_df['Cloudiness']

# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north_hemi, y_values_north_hemi)
regress_values_north_hemi = x_values_north_hemi * slope + intercept
print(regress_values_north_hemi)

# Create Plot
plt.scatter(x_values_north_hemi,y_values_north_hemi)
plt.plot(x_values_north_hemi,regress_values_north_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(45,32),fontsize=15,color="red")
plt.title(f"Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 1      60.319321
# 2      60.246332
# 3      60.280159
# 5      60.183868
# 11     60.176479
#          ...
# 556    60.280267
# 557    60.263648
# 558    60.242717
# 561    60.249020
# 562    60.253454
# Name: Lat, Length: 396, dtype: float64
# The r^2-value is: 2.6558942403888975e-06

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_south_hemi = south_hemi_df['Lat']
y_values_south_hemi = south_hemi_df['Cloudiness']

# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south_hemi, y_values_south_hemi)
regress_values_south_hemi = x_values_south_hemi * slope + intercept
print(regress_values_south_hemi)

# Create Plot
plt.scatter(x_values_south_hemi,y_values_south_hemi)
plt.plot(x_values_south_hemi,regress_values_south_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-53,42),fontsize=15,color="red")
plt.title(f"Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 0      37.068768
# 4      43.637382
# 6      34.028504
# 7      37.344545
# 8      39.842233
#          ...
# 546    39.199154
# 551    47.439919
# 553    43.717925
# 559    45.065578
# 560    49.220491
# Name: Lat, Length: 167, dtype: float64
# The r^2-value is: 0.011551873985386011

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
 There are very week linear relationship between latitute and cloudiness for the south, while the north hemisphere indicates quite strong postive relationship.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_north_hemi = north_hemi_df['Lat']
y_values_north_hemi = north_hemi_df['Wind Speed']

# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north_hemi, y_values_north_hemi)
regress_values_north_hemi = x_values_north_hemi * slope + intercept
print(regress_values_north_hemi)

# Create Plot
plt.scatter(x_values_north_hemi,y_values_north_hemi)
plt.plot(x_values_north_hemi,regress_values_north_hemi ,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(45,13),fontsize=15,color="red")
plt.title(f"Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 1      3.884908
# 2      3.720428
# 3      3.796656
# 5      3.579664
# 11     3.563014
#          ...
# 556    3.796899
# 557    3.759449
# 558    3.712280
# 561    3.726485
# 562    3.736477
# Name: Lat, Length: 396, dtype: float64
# The r^2-value is: 0.003253848425010469

# %%
# Define x_values and y_values for Nortern Hemisphere
x_values_south_hemi = south_hemi_df['Lat']
y_values_south_hemi = south_hemi_df['Wind Speed']


# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south_hemi, y_values_south_hemi)
regress_values_south_hemi = x_values_south_hemi * slope + intercept
print(regress_values_south_hemi)

# Create Plot
plt.scatter(x_values_south_hemi,y_values_south_hemi)
plt.plot(x_values_south_hemi,regress_values_south_hemi,"r-")

# Define the line equation
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-52,9),fontsize=15,color="red")
plt.title(f"Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# City_ID
# 0      4.236804
# 4      4.018482
# 6      4.337854
# 7      4.227638
# 8      4.144622
#          ...
# 546    4.165996
# 551    3.892096
# 553    4.015805
# 559    3.971012
# 560    3.832914
# Name: Lat, Length: 167, dtype: float64
# The r^2-value is: 0.002025065208987072

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
 There are very week linear relationship between latitute and cloudiness for the south and north hemisphere.
